# %% [markdown]
# <a href="https://colab.research.google.com/github/CamFuenzalidaC/super_mercado/blob/main/Actividad_MD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#iportamos librerias
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/CamFuenzalidaC/super_mercado/main/oasis_live_25.csv"
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    concert_id        date        city country_or_constituent_country  \
# 0           1  2025-07-04     Cardiff                          Wales
# 1           2  2025-07-05     Cardiff                          Wales
# 2           3  2025-07-11  Manchester                        England
# 3           4  2025-07-12  Manchester                        England
# 4           5  2025-07-16  Manchester                        England
#
#   sovereign_country                 venue residency_key  \
# 0    United Kingdom  Principality Stadium       cardiff
# 1    United Kingdom  Principality Stadium       cardiff
# 2    United Kingdom           Heaton Park    manchester
# 3    United Kingdom           Heaton Park    manchester
# 4    United Kingdom           Heaton Park    manchester
#
#    shows_in_city_residency  attendance_reported_city_residency  \
# 0                        2                              140000
# 1                        2                              140000
# ...

# %%
df.columns #analicis especifico de la columnas
# Out:
# Index(['concert_id', 'date', 'city', 'country_or_constituent_country',
#        'sovereign_country', 'venue', 'residency_key',
#        'shows_in_city_residency', 'attendance_reported_city_residency',
#        'attendance_scope_note', 'attendance_estimated_per_concert',
#        'gross_reported_usd_per_concert', 'avg_ticket_price_usd_pollstar',
#        'gross_estimated_usd_per_concert', 'gross_estimation_note',
#        'setlist_variant', 'setlist', 'source_tour_dates_attendance_url',
#        'source_tour_financials_url', 'source_setlist_url'],
#       dtype='object')

# %%
df['city'].value_counts() # variables categoricas encontradas: obejetivo city
# Out:
# city
# London             7
# Manchester         5
# Edinburgh          3
# Melbourne          3
# Cardiff            2
# Toronto            2
# East Rutherford    2
# Pasadena           2
# Dublin             2
# São Paulo          2
# Mexico City        2
# Tokyo              2
# Sydney             2
# Buenos Aires       2
# Chicago            1
# Goyang             1
# Santiago           1
# Name: count, dtype: int64

# %%
df['city'].value_counts().count() #cuantas filas tiene la variable city
# Out:
# np.int64(17)

# %%
df['city'].unique() #extrar los datos unicos de city
# Out:
# array(['Cardiff', 'Manchester', 'London', 'Edinburgh', 'Dublin',
#        'Toronto', 'Chicago', 'East Rutherford', 'Pasadena', 'Mexico City',
#        'Goyang', 'Tokyo', 'Melbourne', 'Sydney', 'Buenos Aires',
#        'Santiago', 'São Paulo'], dtype=object)

# %%
df.isnull().sum() # variables nulas
# Out:
# concert_id                             0
# date                                   0
# city                                   0
# country_or_constituent_country         0
# sovereign_country                      0
# venue                                  0
# residency_key                          0
# shows_in_city_residency                0
# attendance_reported_city_residency     0
# attendance_scope_note                  0
# attendance_estimated_per_concert       0
# gross_reported_usd_per_concert        41
# avg_ticket_price_usd_pollstar          0
# gross_estimated_usd_per_concert        0
# gross_estimation_note                  0
# setlist_variant                        0
# setlist                                0
# source_tour_dates_attendance_url       0
# source_tour_financials_url             0
# source_setlist_url                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# concert_id                             0
# date                                   0
# city                                   0
# country_or_constituent_country         0
# sovereign_country                      0
# venue                                  0
# residency_key                          0
# shows_in_city_residency                0
# attendance_reported_city_residency     0
# attendance_scope_note                  0
# attendance_estimated_per_concert       0
# gross_reported_usd_per_concert        41
# avg_ticket_price_usd_pollstar          0
# gross_estimated_usd_per_concert        0
# gross_estimation_note                  0
# setlist_variant                        0
# setlist                                0
# source_tour_dates_attendance_url       0
# source_tour_financials_url             0
# source_setlist_url                     0
# dtype: int64

# %%
#ponevariable estadisticas en forma numerica
df.describe().round()
# Out:
#        concert_id  shows_in_city_residency  \
# count        41.0                     41.0
# mean         21.0                      3.0
# std          12.0                      1.0
# min           1.0                      1.0
# 25%          11.0                      2.0
# 50%          21.0                      2.0
# 75%          31.0                      3.0
# max          41.0                      5.0
#
#        attendance_reported_city_residency  attendance_estimated_per_concert  \
# count                                41.0                              41.0
# mean                             202537.0                           70244.0
# std                              112741.0                           10945.0
# min                               52000.0                           50000.0
# 25%                              130000.0                           60000.0
# 50%                              162000.0                           70000.0
# ...

# %%
df.info() #muestras los tispos de datos y nulos de la dt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   concert_id                          41 non-null     int64
#  1   date                                41 non-null     object
#  2   city                                41 non-null     object
#  3   country_or_constituent_country      41 non-null     object
#  4   sovereign_country                   41 non-null     object
#  5   venue                               41 non-null     object
#  6   residency_key                       41 non-null     object
#  7   shows_in_city_residency             41 non-null     int64
#  8   attendance_reported_city_residency  41 non-null     int64
#  9   attendance_scope_note               41 non-null     object
#  10  attendance_estimated_per_concert    41 non-null     int64
# ...

# %%
df.shape # ver las dimensiones
# Out:
# (41, 20)

# %%
df_limpio= df.dropna() #elimina los valores nulos

# %%
df_limpio.to_csv("nuevo_csv_lmpio.csv")
